# %%
import pandas as pd

# %%
data_model=pd.read_csv('mtcars.csv')

# %%
data_model
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
import numpy as np

# %%
best_mpg=data_model.model[(data_model["mpg"]==np.max(data_model.mpg))]

# %%
#question1 
best_mpg
# Out:
# 30    Maserati Bora
# Name: model, dtype: object

# %%
best_mpg=data_model.model[(data_model["mpg"]==np.min(data_model.mpg))]

# %%
#question2
best_mpg
# Out:
# 30    Maserati Bora
# Name: model, dtype: object

# %%
best_mpg=data_model.model[(data_model["hp"]==np.max(data_model.hp))]

# %%
#question3
best_mpg
# Out:
# 30    Maserati Bora
# Name: model, dtype: object

# %%
#question4
data_model['disp'].describe()
# Out:
# count     32.000000
# mean     230.721875
# std      123.938694
# min       71.100000
# 25%      120.825000
# 50%      196.300000
# 75%      326.000000
# max      472.000000
# Name: disp, dtype: float64

# %%
#question5
np.median(data_model.hp)
# Out:
# 123.0

# %%
#question6
pd.crosstab(data_model.mpg,data_model.am==0,margins=True,margins_name='Total')
# Out:
# am     False  True  Total
# mpg
# 10.4       0     2      2
# 13.3       0     1      1
# 14.3       0     1      1
# 14.7       0     1      1
# 15.0       1     0      1
# 15.2       0     2      2
# 15.5       0     1      1
# 15.8       1     0      1
# 16.4       0     1      1
# 17.3       0     1      1
# 17.8       0     1      1
# 18.1       0     1      1
# 18.7       0     1      1
# 19.2       0     2      2
# 19.7       1     0      1
# 21.0       2     0      2
# 21.4       1     1      2
# 21.5       0     1      1
# 22.8       1     1      2
# 24.4       0     1      1
# 26.0       1     0      1
# 27.3       1     0      1
# 30.4       2     0      2
# 32.4       1     0      1
# 33.9       1     0      1
# Total     13    19     32

# %%
import matplotlib.pyplot as pt

# %%
#question7
data_model.hist(column='mpg')
# Out:
# array([[<AxesSubplot:title={'center':'mpg'}>]], dtype=object)

# %%
import seaborn

# %%
import seaborn as sns

# %%
#question8
pt.figure(figsize=(8,8))
sns.boxplot(data=data_model,y="mpg",x="cyl")
pt.show()

# %%
#question9

# %%
pd.crosstab(data_model.am==0,data_model.am==1)
# Out:
# am     False  True
# am
# False      0    13
# True      19     0

# %%
#question10
pd.crosstab(data_model.am,data_model.cyl)
# Out:
# cyl  4  6   8
# am
# 0    3  4  12
# 1    8  3   2

# %%
#question11
data_model['wt'].corr(data_model['mpg'])
# Out:
# -0.8676593765172281
